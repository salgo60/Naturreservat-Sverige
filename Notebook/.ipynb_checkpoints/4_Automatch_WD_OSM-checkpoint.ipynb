# %% [markdown]
# * [#4](https://github.com/salgo60/Naturreservat-Sverige/issues/4)
# * denna Notebook [4_Automatch_WD_OSM](https://github.com/salgo60/Naturreservat-Sverige/blob/main/Notebook/4_Automatch_WD_OSM.ipynb)

# %%
from SPARQLWrapper import SPARQLWrapper, JSON
import pandas as pd

sparql = SPARQLWrapper("https://query.wikidata.org/sparql")

query = """
SELECT ?item ?itemLabel ?nrvid ?lat ?lon ?url WHERE {
  # ?item wdt:P31 wd:Q179049;
        wdt:P17 wd:Q34;
        wdt:P625 ?coord;
        wdt:P3613 ?nrvid.

  MINUS { ?item wdt:P402 ?rel. }
  MINUS { ?item wdt:P10689 ?way. }
  MINUS { ?item wdt:P576 ?dissolved. }

  BIND(geof:latitude(?coord) AS ?lat)
  BIND(geof:longitude(?coord) AS ?lon)
  MINUS {
  # ?item p:P10689 ?stmt.
  # ?stmt prov:wasDerivedFrom ?ref.
  # ?ref pr:P854 ?url.
  FILTER(CONTAINS(STR(?url), "openstreetmap.org/note"))
  } 
  MINUS {
  # ?item p:P402 ?stmt.
  # ?stmt prov:wasDerivedFrom ?ref.
  # ?ref pr:P854 ?url.
  FILTER(CONTAINS(STR(?url), "openstreetmap.org/note"))
}
  SERVICE wikibase:label { bd:serviceParam wikibase:language "sv,en". }
}
"""

sparql.setQuery(query)
sparql.setReturnFormat(JSON)
data = sparql.query().convert()

rows = []
for r in data["results"]["bindings"]:
    rows.append({
        "wd": r["item"]["value"],
        "label": r["itemLabel"]["value"],
        "nrvid": r["nrvid"]["value"],
        "lat": float(r["lat"]["value"]),
        "lon": float(r["lon"]["value"]),
    })

wd_df = pd.DataFrame(rows)
wd_df.head()
# Out:
#                                          wd                       label  \
# 0  http://www.wikidata.org/entity/Q10509731         Grängshytteforsarna
# 1  http://www.wikidata.org/entity/Q10524585                       Hissö
# 2  http://www.wikidata.org/entity/Q11872000  Klusåbergets naturreservat
# 3  http://www.wikidata.org/entity/Q18291412                   Kronoberg
# 4  http://www.wikidata.org/entity/Q18331194              Kycklingkullen
#
#      nrvid        lat        lon
# 0  2000253  59.716510  14.782602
# 1  2002397  56.957118  14.799846
# 2  2044059  66.156619  20.827351
# 3  2002396  56.932458  14.782011
# 4  2027491  57.895173  13.451222

# %%
wd_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   wd      201 non-null    object
#  1   label   201 non-null    object
#  2   nrvid   201 non-null    object
#  3   lat     201 non-null    float64
#  4   lon     201 non-null    float64
# dtypes: float64(2), object(3)
# memory usage: 8.0+ KB

# %%
import requests

overpass_query = """
[out:json][timeout:60];
(
  nwr["ref:NVRID"];
  nwr["leisure"="nature_reserve"];
  nwr["wikidata"];
);
out center tags;
"""

url = "https://overpass-api.de/api/interpreter"
resp = requests.post(url, data={"data": overpass_query})
osm = resp.json()

# %%
osm_rows = []

for el in osm["elements"]:
    tags = el.get("tags", {})
    
    lat = el.get("lat") or el.get("center", {}).get("lat")
    lon = el.get("lon") or el.get("center", {}).get("lon")
    if not lat or not lon:
        continue

    osm_rows.append({
        "type": el["type"],
        "id": el["id"],
        "lat": lat,
        "lon": lon,
        "wikidata": tags.get("wikidata"),
        "nrvid": tags.get("ref:NVRID"),
        "leisure": tags.get("leisure")
    })

osm_df = pd.DataFrame(osm_rows)
osm_df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
wd_df
# Out:
#                                              wd  \
# 0      http://www.wikidata.org/entity/Q10501019
# 1      http://www.wikidata.org/entity/Q10509731
# 2      http://www.wikidata.org/entity/Q10524585
# 3      http://www.wikidata.org/entity/Q10531425
# 4      http://www.wikidata.org/entity/Q10531844
# ...                                         ...
# 1276  http://www.wikidata.org/entity/Q133794797
# 1277  http://www.wikidata.org/entity/Q133794802
# 1278  http://www.wikidata.org/entity/Q133794803
# 1279  http://www.wikidata.org/entity/Q133794800
# 1280  http://www.wikidata.org/entity/Q133794801
#
#                                      label    nrvid        lat        lon
# 0                            Fårhagsberget  2002288  57.249529  16.250354
# 1                      Grängshytteforsarna  2000253  59.716510  14.782602
# 2                                    Hissö  2002397  56.957118  14.799846
# 3                          Hällingsåfallet  2001199  64.350681  14.390908
# 4                          Hästbergs klack  2002084  60.329444  15.066944
# ...                                    ...      ...        ...        ...
# 1276            Junkerkölens naturreservat  2055859  65.904140  20.906590
# 1277        Stora Njakajaure naturreservat  2062481  65.930270  18.185490
# 1278  Naulajärvi-Kirvesvuoma naturreservat  2062781  66.794940  21.244600
# 1279       Stor-Getarbergets naturreservat  2063681  65.613910  18.389610
# 1280            Dábmukjávrre naturreservat  2062141  66.546480  20.587170
#
# [1281 rows x 5 columns]

# %%
import geopandas as gpd

wd_gdf = gpd.GeoDataFrame(
    wd_df,
    geometry=gpd.points_from_xy(wd_df.lon, wd_df.lat),
    crs="EPSG:4326"
)

# %%
wd_gdf.head()
# Out:
#                                          wd                label    nrvid  \
# 0  http://www.wikidata.org/entity/Q10501019        Fårhagsberget  2002288
# 1  http://www.wikidata.org/entity/Q10509731  Grängshytteforsarna  2000253
# 2  http://www.wikidata.org/entity/Q10524585                Hissö  2002397
# 3  http://www.wikidata.org/entity/Q10531425      Hällingsåfallet  2001199
# 4  http://www.wikidata.org/entity/Q10531844      Hästbergs klack  2002084
#
#          lat        lon                   geometry
# 0  57.249529  16.250354  POINT (16.25035 57.24953)
# 1  59.716510  14.782602   POINT (14.7826 59.71651)
# 2  56.957118  14.799846  POINT (14.79985 56.95712)
# 3  64.350681  14.390908  POINT (14.39091 64.35068)
# 4  60.329444  15.066944  POINT (15.06694 60.32944)

# %%
import requests
import osm2geojson

overpass_query = """
[out:json][timeout:120];
(
  relation["boundary"="protected_area"](55,11,69,24);
  way["boundary"="protected_area"](55,11,69,24);
  relation["leisure"="nature_reserve"](55,11,69,24);
  way["leisure"="nature_reserve"](55,11,69,24);
);
out geom;
"""

url = "https://overpass-api.de/api/interpreter"
r = requests.post(url, data={"data": overpass_query})
print(r.status_code)
print(r.text[:500])
# Out:
# 200
# {
#   "version": 0.6,
#   "generator": "Overpass API 0.7.62.10 2d4cfc48",
#   "osm3s": {
#     "timestamp_osm_base": "2026-02-17T21:41:00Z",
#     "copyright": "The data included in this document is from www.openstreetmap.org. The data is made available under ODbL."
#   },
#   "elements": [
#
# {
#   "type": "way",
#   "id": 4157140,
#   "bounds": {
#     "minlat": 59.2178868,
#     "minlon": 10.5385463,
#     "maxlat": 59.2198617,
#     "maxlon": 10.5404155
#   },
#   "nodes": [
#     23666848,
#     4776161962,
#     4776161963,

# %%
import json
import geopandas as gpd

# --- 1) Säker JSON-parse ---
if not r.text.strip().startswith("{"):
    raise Exception("Overpass returnerade inte JSON:\n" + r.text[:1000])

osm_json = r.json()

# --- 2) Konvertera till GeoJSON ---
geojson = osm2geojson.json2geojson(osm_json)

# --- 3) Bygg GeoDataFrame ---
osm_gdf = gpd.GeoDataFrame.from_features(geojson["features"], crs="EPSG:4326")

print("Antal features:", len(osm_gdf))

# --- 4) Rensa upp geometrier ---
osm_gdf = osm_gdf[osm_gdf.geometry.notnull()]

# Shapely 2.x
try:
    osm_gdf["geometry"] = osm_gdf["geometry"].make_valid()
except:
    # fallback för Shapely <2
    osm_gdf["geometry"] = osm_gdf["geometry"].buffer(0)

# ta bort fortfarande trasiga
osm_gdf = osm_gdf[osm_gdf.is_valid]

print("Efter cleanup:", len(osm_gdf))

# --- 5) (Rekommenderat) reprojicera för snabbare spatial join ---
osm_gdf = osm_gdf.to_crs(3857)
# Out:
# Failed to convert relation to shape:
#  GEOSException('TopologyException: side location conflict at 11.675698990196006 58.121017776299496. This can occur if the input geometry is invalid.') {'bounds': {'maxlat': 58.1220316,
#             'maxlon': 11.707381,
#             'minlat': 58.0991892,
#             'minlon': 11.6512585},
#  'id': 1026566,
#  'members': [{'geometry': [{'lat': 58.1114279, 'lon': 11.6652596},
#                            {'lat': 58.1112097, 'lon': 11.6650665},
#                            {'lat': 58.1055387, 'lon': 11.6552496},
#                            {'lat': 58.0997448, 'lon': 11.6512585}],
#               'ref': 66106125,
#               'role': 'outer',
#               'type': 'way',
#               'used': 1026566},
#              {'geometry': [{'lat': 58.1215448, 'lon': 11.6762727},
#                            {'lat': 58.1214831, 'lon': 11.6766882},
#                            {'lat': 58.1214292, 'lon': 11.6769663},
#                            {'lat': 58.1214033, 'lon': 11.6772751},
#                            {'lat': 58.1213923, 'lon': 11.6774929},
#                            {'lat': 58.1213285, 'lon': 11.6777424},
#                            {'lat': 58.1212347, 'lon': 11.6781737},
#                            {'lat': 58.1212004, 'lon': 11.6785047},
#                            {'lat': 58.1211979, 'lon': 11.6789806},
#                            {'lat': 58.1212032, 'lon': 11.6796978},
#                            {'lat': 58.1212351, 'lon': 11.6801273},
#                            {'lat': 58.1213354, 'lon': 11.6807272},
#                            {'lat': 58.1214408, 'lon': 11.6814837},
#                            {'lat': 58.121475, 'lon': 11.6819852},
#                            {'lat': 58.1215025, 'lon': 11.6825553},
#                            {'lat': 58.1215271, 'lon': 11.6827606},
#                            {'lat': 58.1215987, 'lon': 11.6833044},
#                            {'lat': 58.1216708, 'lon': 11.6835891},
#                            {'lat': 58.1217892, 'lon': 11.6839152},
#                            {'lat': 58.1220316, 'lon': 11.6844605},
#                            {'lat': 58.1219113, 'lon': 11.6849644},
#                            {'lat': 58.1201749, 'lon': 11.6848411},
#                            {'lat': 58.1196005, 'lon': 11.6840537},
#                            {'lat': 58.119357, 'lon': 11.6837506},
#                            {'lat': 58.1191804, 'lon': 11.6835714},
#                            {'lat': 58.1190049, 'lon': 11.6834261},
#                            {'lat': 58.1187612, 'lon': 11.6832036},
#                            {'lat': 58.1179253, 'lon': 11.6830802},
#                            {'lat': 58.1176689, 'lon': 11.6829488},
#                            {'lat': 58.1174904, 'lon': 11.6827342},
#                            {'lat': 58.1172652, 'lon': 11.6823748},
#                            {'lat': 58.1171405, 'lon': 11.682018},
#                            {'lat': 58.1170442, 'lon': 11.6816103},
#                            {'lat': 58.1165781, 'lon': 11.6819268},
#                            {'lat': 58.1166602, 'lon': 11.6829407},
#                            {'lat': 58.116418, 'lon': 11.6832572},
#                            {'lat': 58.1157436, 'lon': 11.6836274},
#                            {'lat': 58.1154942, 'lon': 11.6838795},
#                            {'lat': 58.1151269, 'lon': 11.6846941},
#                            {'lat': 58.1150692, 'lon': 11.6854888},
#                            {'lat': 58.1151486, 'lon': 11.6869157},
#                            {'lat': 58.1151996, 'lon': 11.6878438},
#                            {'lat': 58.1151823, 'lon': 11.6889042},
#                            {'lat': 58.1150522, 'lon': 11.6910356},
#                            {'lat': 58.1149522, 'lon': 11.6929095},
#                            {'lat': 58.1150876, 'lon': 11.6947961},
#                            {'lat': 58.1157025, 'lon': 11.6978806},
#                            {'lat': 58.1161643, 'lon': 11.699329},
#                            {'lat': 58.11634, 'lon': 11.6991359},
#                            {'lat': 58.1177142, 'lon': 11.7005038},
#                            {'lat': 58.1190006, 'lon': 11.7012119},
#                            {'lat': 58.1188703, 'lon': 11.7044627},
#                            {'lat': 58.118536, 'lon': 11.704629},
#                            {'lat': 58.118179, 'lon': 11.7047095},
#                            {'lat': 58.1173374, 'lon': 11.707381}],
#               'ref': 66106088,
#               'role': 'outer',
#               'type': 'way',
#               'used': 1026566},
#              {'geometry': [{'lat': 58.1173374, 'lon': 11.707381},
#                            {'lat': 58.1165596, 'lon': 11.7046183},
#                            {'lat': 58.1158201, 'lon': 11.7033201},
#                            {'lat': 58.1144685, 'lon': 11.7017323},
#                            {'lat': 58.1139216, 'lon': 11.7017645},
#                            {'lat': 58.1122199, 'lon': 11.6970304},
#                            {'lat': 58.1107648, 'lon': 11.6879511},
#                            {'lat': 58.1041328, 'lon': 11.6783488},
#                            {'lat': 58.1019304, 'lon': 11.6652542}],
#               'ref': 764562355,
#               'role': 'outer',
#               'type': 'way',
#               'used': 1026566},
#              {'geometry': [{'lat': 58.1019304, 'lon': 11.6652542},
#                            {'lat': 58.0991933, 'lon': 11.6579294},
#                            {'lat': 58.0991892, 'lon': 11.6572398},
#                            {'lat': 58.0997448, 'lon': 11.6512585}],
#               'ref': 764562354,
#               'role': 'outer',
#               'type': 'way',
#               'used': 1026566},
#              {'geometry': [{'lat': 58.1114222, 'lon': 11.6691327},
#                            {'lat': 58.1102873, 'lon': 11.669696},
#                            {'lat': 58.1108611, 'lon': 11.6735369},
#                            {'lat': 58.1121222, 'lon': 11.6734457},
#                            {'lat': 58.1114222, 'lon': 11.6691327}],
#               'ref': 839772897,
#               'role': 'inner',
#               'type': 'way',
#               'used': 1026566},
#              {'geometry': [{'lat': 58.1215448, 'lon': 11.6762727},
#                            {'lat': 58.1211807, 'lon': 11.6758168},
#                            {'lat': 58.1203053, 'lon': 11.6751838},
#                            {'lat': 58.1193675, 'lon': 11.6741592},
#                            {'lat': 58.1130899, 'lon': 11.66659},
#                            {'lat': 58.1114279, 'lon': 11.6652596}],
#               'ref': 839772896,
#               'role': 'outer',
#               'type': 'way',
#               'used': 1026566}],
#  'tags': {'leisure': 'nature_reserve',
#           'lst:area_ha': '296.61',
#           'lst:ref': '2000773',
#           'lst:tillkomst': '1977-03-31',
#           'lst:url': 'http://www.lansstyrelsen.se/vastragotaland/amnen/Naturvard/Naturreservat/Orust/Svanvik',
#           'name': 'Svanviks naturreservat',
#           'source': 'Länsstyrelsen i Västra Götalands län (gis.lst.se)',
#           'type': 'multipolygon',
#           'wikidata': 'Q18333139'},
#  'type': 'relation'}
# Failed to convert relation to shape:
#  TypeError("'GeometryCollection' object is not iterable") {'bounds': {'maxlat': 57.6337664,
#             'maxlon': 11.9309558,
#             'minlat': 57.6292911,
#             'minlon': 11.9237566},
#  'id': 3399597,
#  'members': [{'geometry': [{'lat': 57.6292987, 'lon': 11.9262796},
#                            {'lat': 57.6293459, 'lon': 11.9261737},
#                            {'lat': 57.6294257, 'lon': 11.9261367},
#                            {'lat': 57.6294948, 'lon': 11.9260999},
#                            {'lat': 57.6295522, 'lon': 11.9259956},
#                            {'lat': 57.6295984, 'lon': 11.9259395},
#                            {'lat': 57.6296164, 'lon': 11.9258134},
#                            {'lat': 57.6295906, 'lon': 11.925509},
#                            {'lat': 57.6295817, 'lon': 11.9254536},
#                            {'lat': 57.6296107, 'lon': 11.9252676}],
#               'ref': 1132985927,
#               'role': 'outer',
#               'type': 'way',
#               'used': 3399597},
#              {'geometry': [{'lat': 57.6299122, 'lon': 11.924729},
#                            {'lat': 57.6300353, 'lon': 11.9249067},
#                            {'lat': 57.6302291, 'lon': 11.9251826},
#                            {'lat': 57.6302864, 'lon': 11.9251988},
#                            {'lat': 57.6303368, 'lon': 11.9252293},
#                            {'lat': 57.6304062, 'lon': 11.9252344},
#                            {'lat': 57.6304757, 'lon': 11.9252318},
#                            {'lat': 57.630526, 'lon': 11.9251759},
#                            {'lat': 57.6305955, 'lon': 11.925125},
#                            {'lat': 57.6306622, 'lon': 11.9250309},
#                            {'lat': 57.6307126, 'lon': 11.9249266},
#                            {'lat': 57.6307943, 'lon': 11.9248503},
#                            {'lat': 57.6308447, 'lon': 11.9248071},
#                            {'lat': 57.6309087, 'lon': 11.9247028},
#                            {'lat': 57.6309809, 'lon': 11.9245629},
#                            {'lat': 57.6310408, 'lon': 11.9244841},
#                            {'lat': 57.6311061, 'lon': 11.9244128},
#                            {'lat': 57.6305733, 'lon': 11.9281365},
#                            {'lat': 57.6305387, 'lon': 11.9280645},
#                            {'lat': 57.6304828, 'lon': 11.9280393},
#                            {'lat': 57.6304154, 'lon': 11.9280429},
#                            {'lat': 57.6303769, 'lon': 11.9280933},
#                            {'lat': 57.6303191, 'lon': 11.9281041},
#                            {'lat': 57.6302787, 'lon': 11.9280717},
#                            {'lat': 57.6302536, 'lon': 11.9280142},
#                            {'lat': 57.6302594, 'lon': 11.9278847},
#                            {'lat': 57.6303114, 'lon': 11.9277336},
#                            {'lat': 57.6303326, 'lon': 11.9276221}],
#               'ref': 253660544,
#               'role': 'inner',
#               'type': 'way',
#               'used': 3399597},
#              {'geometry': [{'lat': 57.6292911, 'lon': 11.9267038},
#                            {'lat': 57.6292987, 'lon': 11.9262796}],
#               'ref': 1132985891,
#               'role': 'outer',
#               'type': 'way',
#               'used': 3399597},
#              {'geometry': [{'lat': 57.6296107, 'lon': 11.9252676},
#                            {'lat': 57.6299122, 'lon': 11.924729}],
#               'ref': 1132985922,
#               'role': 'outer',
#               'type': 'way',
#               'used': 3399597}],
#  'tags': {'landuse': 'forest',
#           'leisure': 'nature_reserve',
#           'name': 'Hult Åsens naturreservat',
#           'type': 'multipolygon'},
#  'type': 'relation'}
# Failed to convert relation to shape:
#  GEOSException('TopologyException: side location conflict at 24.824433515299191 59.557702046936804. This can occur if the input geometry is invalid.') {'bounds': {'maxlat': 59.5627208,
#             'maxlon': 24.8366311,
#             'minlat': 59.5426586,
#             'minlon': 24.8047056},
#  'id': 19119178,
#  'members': [{'geometry': [{'lat': 59.5540431, 'lon': 24.8326828},
#                            {'lat': 59.5540214, 'lon': 24.8327059},
#                            {'lat': 59.5532046, 'lon': 24.8330829},
#                            {'lat': 59.5529454, 'lon': 24.8332025},
#                            {'lat': 59.5455152, 'lon': 24.8366311},
#                            {'lat': 59.5442784, 'lon': 24.8269611},
#                            {'lat': 59.5426586, 'lon': 24.8142968},
#                            {'lat': 59.5483032, 'lon': 24.8115924},
#                            {'lat': 59.5477726, 'lon': 24.8076468},
#                            {'lat': 59.5483772, 'lon': 24.807116},
#                            {'lat': 59.5494138, 'lon': 24.8067577},
#                            {'lat': 59.5504764, 'lon': 24.8063931},
#                            {'lat': 59.5508329, 'lon': 24.8063154},
#                            {'lat': 59.5528492, 'lon': 24.8056187},
#                            {'lat': 59.552911, 'lon': 24.8062794},
#                            {'lat': 59.5537669, 'lon': 24.8060477},
#                            {'lat': 59.5537204, 'lon': 24.805303},
#                            {'lat': 59.5559627, 'lon': 24.8047056},
#                            {'lat': 59.5561177, 'lon': 24.8049517},
#                            {'lat': 59.5562508, 'lon': 24.8052518},
#                            {'lat': 59.55642, 'lon': 24.8057293},
#                            {'lat': 59.5570505, 'lon': 24.8076108},
#                            {'lat': 59.5574308, 'lon': 24.808901},
#                            {'lat': 59.5573536, 'lon': 24.8089821},
#                            {'lat': 59.556996, 'lon': 24.8090401},
#                            {'lat': 59.5569279, 'lon': 24.80952},
#                            {'lat': 59.5569404, 'lon': 24.8096651},
#                            {'lat': 59.5569373, 'lon': 24.8097253},
#                            {'lat': 59.556914, 'lon': 24.8099774},
#                            {'lat': 59.5569113, 'lon': 24.8100774},
#                            {'lat': 59.5569157, 'lon': 24.8102027},
#                            {'lat': 59.5569498, 'lon': 24.8104729},
#                            {'lat': 59.5569615, 'lon': 24.8106083},
#                            {'lat': 59.5569727, 'lon': 24.8107959},
#                            {'lat': 59.5569898, 'lon': 24.81102},
#                            {'lat': 59.5570588, 'lon': 24.8118016},
#                            {'lat': 59.5571457, 'lon': 24.8123636},
#                            {'lat': 59.5571838, 'lon': 24.8125815},
#                            {'lat': 59.5585901, 'lon': 24.8130607},
#                            {'lat': 59.5589595, 'lon': 24.8126191},
#                            {'lat': 59.5590563, 'lon': 24.8125514},
#                            {'lat': 59.5591339, 'lon': 24.8124451},
#                            {'lat': 59.5603917, 'lon': 24.8110061},
#                            {'lat': 59.5605029, 'lon': 24.8111428},
#                            {'lat': 59.5605688, 'lon': 24.8111994},
#                            {'lat': 59.5606037, 'lon': 24.8112304},
#                            {'lat': 59.5606037, 'lon': 24.8113295},
#                            {'lat': 59.5606176, 'lon': 24.8114136},
#                            {'lat': 59.5606593, 'lon': 24.8115684},
#                            {'lat': 59.5607288, 'lon': 24.8117878},
#                            {'lat': 59.5607885, 'lon': 24.8119498},
#                            {'lat': 59.5608318, 'lon': 24.8120315},
#                            {'lat': 59.5609263, 'lon': 24.8121578},
#                            {'lat': 59.5611416, 'lon': 24.8123841},
#                            {'lat': 59.5613489, 'lon': 24.8125452},
#                            {'lat': 59.561448, 'lon': 24.812603},
#                            {'lat': 59.5615865, 'lon': 24.8126585},
#                            {'lat': 59.5616107, 'lon': 24.8126893},
#                            {'lat': 59.5616244, 'lon': 24.8127578},
#                            {'lat': 59.5616322, 'lon': 24.8129281},
#                            {'lat': 59.5616431, 'lon': 24.8129797},
#                            {'lat': 59.5616673, 'lon': 24.8130259},
#                            {'lat': 59.5617091, 'lon': 24.8130582},
#                            {'lat': 59.5617957, 'lon': 24.8130652},
#                            {'lat': 59.5620614, 'lon': 24.8130505},
#                            {'lat': 59.5622046, 'lon': 24.813173},
#                            {'lat': 59.5624298, 'lon': 24.813552},
#                            {'lat': 59.5626115, 'lon': 24.8133649}],
#               'ref': 1385632228,
#               'role': 'outer',
#               'type': 'way',
#               'used': 19119178},
#              {'geometry': [{'lat': 59.5540431, 'lon': 24.8326828},
#                            {'lat': 59.5540733, 'lon': 24.8324884},
#                            {'lat': 59.5541193, 'lon': 24.8322347},
#                            {'lat': 59.554182, 'lon': 24.8318156},
#                            {'lat': 59.5542009, 'lon': 24.8316422},
#                            {'lat': 59.5542306, 'lon': 24.8314033},
#                            {'lat': 59.5542562, 'lon': 24.8312278},
#                            {'lat': 59.5542791, 'lon': 24.831055},
#                            {'lat': 59.5542974, 'lon': 24.8309458},
#                            {'lat': 59.554331, 'lon': 24.830776},
#                            {'lat': 59.5543684, 'lon': 24.8306294},
#                            {'lat': 59.5544024, 'lon': 24.8304776},
#                            {'lat': 59.55445, 'lon': 24.8302799},
#                            {'lat': 59.5544987, 'lon': 24.8301263},
#                            {'lat': 59.5545462, 'lon': 24.8300222},
#                            {'lat': 59.5545576, 'lon': 24.8299792},
#                            {'lat': 59.5545769, 'lon': 24.8298628},
#                            {'lat': 59.5545883, 'lon': 24.8298036},
#                            {'lat': 59.5546177, 'lon': 24.8296988},
#                            {'lat': 59.5546852, 'lon': 24.8295269},
#                            {'lat': 59.5547253, 'lon': 24.8294303},
#                            {'lat': 59.5547362, 'lon': 24.8294003},
#                            {'lat': 59.5547917, 'lon': 24.8292234},
#                            {'lat': 59.5548496, 'lon': 24.8290306},
#                            {'lat': 59.5548931, 'lon': 24.8288626},
#                            {'lat': 59.5550312, 'lon': 24.828429},
#                            {'lat': 59.5550938, 'lon': 24.8282641},
#                            {'lat': 59.5551681, 'lon': 24.8280291},
#                            {'lat': 59.5552377, 'lon': 24.827799},
#                            {'lat': 59.5553054, 'lon': 24.827619},
#                            {'lat': 59.5554004, 'lon': 24.8273107},
#                            {'lat': 59.5556761, 'lon': 24.826502},
#                            {'lat': 59.5558405, 'lon': 24.8260371},
#                            {'lat': 59.5559451, 'lon': 24.8257174},
#                            {'lat': 59.5560423, 'lon': 24.8254529},
#                            {'lat': 59.5561942, 'lon': 24.8253219},
#                            {'lat': 59.5564163, 'lon': 24.8251239},
#                            {'lat': 59.5565179, 'lon': 24.824933},
#                            {'lat': 59.5566435, 'lon': 24.8247846},
#                            {'lat': 59.556828, 'lon': 24.8246419},
#                            {'lat': 59.5568957, 'lon': 24.8245774},
#                            {'lat': 59.5570201, 'lon': 24.8244157},
#                            {'lat': 59.5571696, 'lon': 24.8243691},
#                            {'lat': 59.5573507, 'lon': 24.8242792},
#                            {'lat': 59.5574886, 'lon': 24.8242647},
#                            {'lat': 59.5575455, 'lon': 24.8242933},
#                            {'lat': 59.5575645, 'lon': 24.8243081},
#                            {'lat': 59.5576275, 'lon': 24.8244161},
#                            {'lat': 59.5577221, 'lon': 24.8244382},
#                            {'lat': 59.5577996, 'lon': 24.8244344},
#                            {'lat': 59.5578633, 'lon': 24.8245444},
#                            {'lat': 59.5579794, 'lon': 24.8246807},
#                            {'lat': 59.558134, 'lon': 24.8248244},
#                            {'lat': 59.5582206, 'lon': 24.8249391},
#                            {'lat': 59.5582722, 'lon': 24.8249853},
#                            {'lat': 59.5582982, 'lon': 24.8250208},
#                            {'lat': 59.5583562, 'lon': 24.8250724},
#                            {'lat': 59.5583847, 'lon': 24.8250957},
#                            {'lat': 59.5584063, 'lon': 24.8251037},
#                            {'lat': 59.5584269, 'lon': 24.8251263},
#                            {'lat': 59.5584737, 'lon': 24.8252128},
#                            {'lat': 59.558532, 'lon': 24.8252953},
#                            {'lat': 59.5586449, 'lon': 24.8255062},
#                            {'lat': 59.5587199, 'lon': 24.825566},
#                            {'lat': 59.5588455, 'lon': 24.8255848},
#                            {'lat': 59.5589824, 'lon': 24.8255563},
#                            {'lat': 59.5591718, 'lon': 24.8255556},
#                            {'lat': 59.5592543, 'lon': 24.8255362},
#                            {'lat': 59.559316, 'lon': 24.8254986},
#                            {'lat': 59.5593937, 'lon': 24.8254481},
#                            {'lat': 59.5594712, 'lon': 24.8254036},
#                            {'lat': 59.5596821, 'lon': 24.8253265},
#                            {'lat': 59.5598049, 'lon': 24.8253482},
#                            {'lat': 59.5598998, 'lon': 24.8254206},
#                            {'lat': 59.5600029, 'lon': 24.8253794},
#                            {'lat': 59.5600507, 'lon': 24.8252806},
#                            {'lat': 59.5601221, 'lon': 24.8250996},
#                            {'lat': 59.5601486, 'lon': 24.8248894},
#                            {'lat': 59.5601566, 'lon': 24.8248486},
#                            {'lat': 59.5602147, 'lon': 24.8246425},
#                            {'lat': 59.5602987, 'lon': 24.824473},
#                            {'lat': 59.5603957, 'lon': 24.824336},
#                            {'lat': 59.5604909, 'lon': 24.824256},
#                            {'lat': 59.5605921, 'lon': 24.8241609},
#                            {'lat': 59.5607994, 'lon': 24.8235107},
#                            {'lat': 59.5608889, 'lon': 24.8233194},
#                            {'lat': 59.5610127, 'lon': 24.8231429},
#                            {'lat': 59.5610952, 'lon': 24.8229712},
#                            {'lat': 59.5611372, 'lon': 24.8229886},
#                            {'lat': 59.5612085, 'lon': 24.8230022},
#                            {'lat': 59.5612741, 'lon': 24.8229815},
#                            {'lat': 59.5613065, 'lon': 24.8229375},
#                            {'lat': 59.5614261, 'lon': 24.8225789},
#                            {'lat': 59.5615998, 'lon': 24.8215722},
#                            {'lat': 59.5617031, 'lon': 24.8211672},
#                            {'lat': 59.5617665, 'lon': 24.8209637},
#                            {'lat': 59.5618274, 'lon': 24.8208972},
#                            {'lat': 59.5618819, 'lon': 24.8208718},
#                            {'lat': 59.5619346, 'lon': 24.8208752},
#                            {'lat': 59.5619604, 'lon': 24.8208994},
#                            {'lat': 59.5619809, 'lon': 24.8209207},
#                            {'lat': 59.5619922, 'lon': 24.820918},
#                            {'lat': 59.5620059, 'lon': 24.8208849},
#                            {'lat': 59.5620623, 'lon': 24.8208115},
#                            {'lat': 59.56207, 'lon': 24.8207543},
#                            {'lat': 59.5620144, 'lon': 24.8205582},
#                            {'lat': 59.5620508, 'lon': 24.8200334},
#                            {'lat': 59.562044, 'lon': 24.8195026},
#                            {'lat': 59.5620501, 'lon': 24.8189686},
#                            {'lat': 59.5620609, 'lon': 24.8184569},
#                            {'lat': 59.5620831, 'lon': 24.8180653},
#                            {'lat': 59.5620906, 'lon': 24.8177367},
#                            {'lat': 59.562108, 'lon': 24.8174813},
#                            {'lat': 59.5621358, 'lon': 24.8173976},
#                            {'lat': 59.5621997, 'lon': 24.8173033},
#                            {'lat': 59.5622449, 'lon': 24.8172589},
#                            {'lat': 59.5622605, 'lon': 24.817162},
#                            {'lat': 59.5623024, 'lon': 24.8167924},
#                            {'lat': 59.5623666, 'lon': 24.8163947},
#                            {'lat': 59.5624122, 'lon': 24.8163652},
#                            {'lat': 59.562428, 'lon': 24.8163525},
#                            {'lat': 59.5624645, 'lon': 24.8163369},
#                            {'lat': 59.5624858, 'lon': 24.81628},
#                            {'lat': 59.5624769, 'lon': 24.8162423},
#                            {'lat': 59.5624183, 'lon': 24.8161192},
#                            {'lat': 59.562413, 'lon': 24.8159841},
#                            {'lat': 59.5624403, 'lon': 24.8158372},
#                            {'lat': 59.5625056, 'lon': 24.8156136},
#                            {'lat': 59.5625699, 'lon': 24.8152893},
#                            {'lat': 59.5626148, 'lon': 24.8150824},
#                            {'lat': 59.5626397, 'lon': 24.8149446},
#                            {'lat': 59.562643, 'lon': 24.8147602},
#                            {'lat': 59.5626514, 'lon': 24.8145108},
#                            {'lat': 59.5627208, 'lon': 24.8141674},
#                            {'lat': 59.5627204, 'lon': 24.814112},
#                            {'lat': 59.5627149, 'lon': 24.8139985},
#                            {'lat': 59.5626998, 'lon': 24.8139032},
#                            {'lat': 59.5626923, 'lon': 24.8137808},
#                            {'lat': 59.5626517, 'lon': 24.8135122},
#                            {'lat': 59.5626244, 'lon': 24.8134156},
#                            {'lat': 59.5626115, 'lon': 24.8133649}],
#               'ref': 45480919,
#               'role': '',
#               'type': 'way',
#               'used': 19119178}],
#  'tags': {'KKR:code': 'KLO5000008',
#           'boundary': 'protected_area',
#           'leisure': 'nature_reserve',
#           'name': 'Rohuneeme maastikukaitseala',
#           'protection_title': 'kohalik kaitstav objekt',
#           'type': 'boundary',
#           'wikidata': 'Q52938183'},
#  'type': 'relation'}
# Antal features: 15320
# Efter cleanup: 15320
#                                             geometry type       id  \
# 0  LINESTRING (1173145.608 8227752.908, 1173151.7...  way  4157140
# 1  LINESTRING (1174791.789 8224760.89, 1174787.31...  way  4157244
# 2  LINESTRING (1175383.508 8224501.954, 1175410.9...  way  4157247
# 3  LINESTRING (1175131.881 8224178.846, 1175156.4...  way  4157249
# 4  LINESTRING (1174739.647 8223743.201, 1174712.1...  way  4157258
#
#                                                 tags  \
# 0  {'access:conditional': 'no @ Apr 15 - Jul 15',...
# 1  {'access:conditional': 'no@Apr 15 - Jul 15', '...
# 2  {'access:conditional': 'no @ Apr 15 - Jul 15',...
# 3  {'access:conditional': 'no @ Apr 15 - Jul 15',...
# 4  {'access:conditional': 'no @ Apr 15 - Jul 15',...
#
#                                                nodes
# 0  [23666848, 4776161962, 4776161963, 4776161970,...
# 1  [23669848, 12560503967, 12560503940, 125605039...
# 2  [23669883, 12560503906, 12560503949, 23669880,...
# 3  [23669946, 23669943, 12560503958, 12560503914,...
# 4  [23670193, 12560517011, 23670191, 23670189, 23...

# %%
osm_gdf.head()
# Out:
#                                             geometry type       id  \
# 0  LINESTRING (1173145.608 8227752.908, 1173151.7...  way  4157140
# 1  LINESTRING (1174791.789 8224760.89, 1174787.31...  way  4157244
# 2  LINESTRING (1175383.508 8224501.954, 1175410.9...  way  4157247
# 3  LINESTRING (1175131.881 8224178.846, 1175156.4...  way  4157249
# 4  LINESTRING (1174739.647 8223743.201, 1174712.1...  way  4157258
#
#                                                 tags  \
# 0  {'access:conditional': 'no @ Apr 15 - Jul 15',...
# 1  {'access:conditional': 'no@Apr 15 - Jul 15', '...
# 2  {'access:conditional': 'no @ Apr 15 - Jul 15',...
# 3  {'access:conditional': 'no @ Apr 15 - Jul 15',...
# 4  {'access:conditional': 'no @ Apr 15 - Jul 15',...
#
#                                                nodes
# 0  [23666848, 4776161962, 4776161963, 4776161970,...
# 1  [23669848, 12560503967, 12560503940, 125605039...
# 2  [23669883, 12560503906, 12560503949, 23669880,...
# 3  [23669946, 23669943, 12560503958, 12560503914,...
# 4  [23670193, 12560517011, 23670191, 23670189, 23...

# %%
osm_gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 15320 entries, 0 to 15319
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   geometry  15320 non-null  geometry
#  1   type      15320 non-null  object
#  2   id        15320 non-null  int64
#  3   tags      15320 non-null  object
#  4   nodes     12272 non-null  object
# dtypes: geometry(1), int64(1), object(3)
# memory usage: 598.6+ KB

# %%
wd_gdf = wd_gdf.to_crs(3857)
osm_gdf = osm_gdf.to_crs(3857)  

import geopandas as gpd

matches = gpd.sjoin(
    wd_gdf,
    osm_gdf[["geometry","id","type","tags"]],
    how="left",
    predicate="within"
)
matches = matches.reset_index(drop=True)

# %%
matches
# Out:
#                                              wd  \
# 0      http://www.wikidata.org/entity/Q10501019
# 1      http://www.wikidata.org/entity/Q10509731
# 2      http://www.wikidata.org/entity/Q10524585
# 3      http://www.wikidata.org/entity/Q10531425
# 4      http://www.wikidata.org/entity/Q10531844
# ...                                         ...
# 1282  http://www.wikidata.org/entity/Q133794797
# 1283  http://www.wikidata.org/entity/Q133794802
# 1284  http://www.wikidata.org/entity/Q133794803
# 1285  http://www.wikidata.org/entity/Q133794800
# 1286  http://www.wikidata.org/entity/Q133794801
#
#                                      label    nrvid        lat        lon  \
# 0                            Fårhagsberget  2002288  57.249529  16.250354
# 1                      Grängshytteforsarna  2000253  59.716510  14.782602
# 2                                    Hissö  2002397  56.957118  14.799846
# 3                          Hällingsåfallet  2001199  64.350681  14.390908
# 4                          Hästbergs klack  2002084  60.329444  15.066944
# ...                                    ...      ...        ...        ...
# 1282            Junkerkölens naturreservat  2055859  65.904140  20.906590
# 1283        Stora Njakajaure naturreservat  2062481  65.930270  18.185490
# 1284  Naulajärvi-Kirvesvuoma naturreservat  2062781  66.794940  21.244600
# 1285       Stor-Getarbergets naturreservat  2063681  65.613910  18.389610
# 1286            Dábmukjávrre naturreservat  2062141  66.546480  20.587170
#
#                               geometry  index_right           id type  \
# 0       POINT (1808981.15 7811292.275)       2139.0  100610138.0  way
# 1       POINT (1645591.71 8336890.679)          NaN          NaN  NaN
# 2      POINT (1647511.325 7751359.082)          NaN          NaN  NaN
# 3      POINT (1601988.559 9439379.672)        480.0   43002332.0  way
# 4      POINT (1677244.583 8473453.153)        623.0   43189852.0  way
# ...                                ...          ...          ...  ...
# 1282   POINT (2327310.953 9850659.193)          NaN          NaN  NaN
# 1283   POINT (2024399.487 9857787.568)          NaN          NaN  NaN
# 1284  POINT (2364938.054 10097881.821)          NaN          NaN  NaN
# 1285   POINT (2047122.021 9771968.057)          NaN          NaN  NaN
# 1286   POINT (2291753.281 10028039.27)          NaN          NaN  NaN
#
#                                                    tags
# 0     {'leisure': 'nature_reserve', 'lst:area_ha': '...
# 1                                                   NaN
# 2                                                   NaN
# 3     {'leisure': 'nature_reserve', 'lst:area_12': '...
# 4     {'leisure': 'nature_reserve', 'lst:ajour': '20...
# ...                                                 ...
# 1282                                                NaN
# 1283                                                NaN
# 1284                                                NaN
# 1285                                                NaN
# 1286                                                NaN
#
# [1287 rows x 10 columns]

# %%
matched = matches[matches["id"].notna()]
print("Matchade:", len(matched))
# Out:
# Matchade: 1078

# %%
missing = matches[matches["id"].isna()]
print("Saknas:", len(missing))
# Out:
# Saknas: 209

# %%
missing.to_crs(4326).to_file(
    "wd_missing_in_osm.geojson",
    driver="GeoJSON"
)

# %%
matches["status"] = matches["id"].notna()
matches["status"].value_counts()
# Out:
# status
# True     1078
# False     209
# Name: count, dtype: int64

# %%
matches.info()

# %%
import folium

# QID från wd-URI
matches["qid"] = matches["wd"].str.split("/").str[-1]

# OSM id till int (när finns)
matches["osm_id"] = matches["id"].dropna().astype(int)

# WGS84 för karta
map_gdf = matches.to_crs(4326) 
m = folium.Map(location=[62,15], zoom_start=5)

layer_match = folium.FeatureGroup(name="Match")
layer_missing = folium.FeatureGroup(name="Saknas")
for _, r in map_gdf.iterrows():

    wd_link = f"https://www.wikidata.org/wiki/{r.qid}"

    osm_link = ""
    if r.status:
        osm_type = r["type"]   # way eller relation
        osm_link = f"https://www.openstreetmap.org/{osm_type}/{int(r.osm_id)}"

    popup = folium.Popup(f"""
        <b>{r.label}</b><br><br>
        WD: <a href="{wd_link}" target="_blank">{r.qid}</a><br>
        OSM: <a href="{osm_link}" target="_blank">
             {r['type']}/{int(r.osm_id) if r.status else "—"}
             </a><br>
        NVRID: {r.nrvid}<br>
        Status: {r.status}
    """, max_width=250)

    marker = folium.CircleMarker(
        [r.geometry.y, r.geometry.x],
        radius=6,
        color="green" if r.status else "red",
        fill=True,
        popup=popup
    )

    if r.status:
        marker.add_to(layer_match)
    else:
        marker.add_to(layer_missing)

layer_match.add_to(m)
layer_missing.add_to(m)

folium.LayerControl().add_to(m)
m.save("wd_vs_osm_QA_map.html")

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9b308c932e31fe47515191a15c9550be {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9b308c932e31fe47515191a15c9550be&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9b308c932e31fe47515191a15c9550be = L.map(
#                 &quot;map_9b308c932e31fe47515191a15c9550be&quot;,
#                 {
#                     center: [62.0, 15.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ac2b7e69e7f6ff0ffb568f454431cf4f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ac2b7e69e7f6ff0ffb568f454431cf4f.addTo(map_9b308c932e31fe47515191a15c9550be);
#
#
#             var feature_group_2d87d7b4b54d07826f70ccae477f7eb4 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var circle_marker_5603bc72adf0bf8752e065ad6046cfcc = L.circleMarker(
#                 [57.249529457, 16.250354156],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_2d87d7b4b54d07826f70ccae477f7eb4);
#
#
#         var popup_427979195a41fa8bb84a929cca6eb9b4 = L.popup({
#   &quot;maxWidth&quot;: 250,
# });
#
#
#
#                 var html_ed76544f024a22fc6716ad4eb3478acd = $(`&lt;div id=&quot;html_ed76544f024a22fc6716ad4eb3478acd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;b&gt;Fårhagsberget&lt;/b&gt;&lt;br&gt;&lt;br&gt;         WD: &lt;a href=&quot;https://www.wikidata.org/wiki/Q10501019&quot; target=&quot;_blank&quot;&gt;Q10501019&lt;/a&gt;&lt;br&gt;         OSM: &lt;a href=&quot;https://www.openstreetmap.org/way/100610138&quot; target=&quot;_blank&quot;&gt;              way/100610138              &lt;/a&gt;&lt;br&gt;         NVRID: 2002288&lt;br&gt;         Status: True     &lt;/div&gt;`)[0];
#                 popup_427979195a41fa8bb84a929cca6eb9b4.setContent(html_ed76544f024a22fc6716ad4eb3478acd);
#
#
#
#         circle_marker_5603bc72adf0bf8752e065ad6046cfcc.bindPopup(popup_427979195a41fa8bb84a929cca6eb9b4)
#         ;
#
#
#
#
#             var circle_marker_f377b26f9d13fd12e40a3dd1afb81c1b = L.circleMarker(
#                 [64.350680656, 14.390908075],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_2d87d7b4b54d07826f70ccae477f7eb4);
#
#
#         var popup_ecd069301c8cc397365ac23ef8f536db = L.popup({
#   &quot;maxWidth&quot;: 250,
# });
#
#
#
#                 var html_2a4b36c26dfd28de7b7927a7a177165c = $(`&lt;div id=&quot;html_2a4b36c26dfd28de7b7927a7a177165c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;b&gt;Hällingsåfallet&lt;/b&gt;&lt;br&gt;&lt;br&gt;         WD: &lt;a href=&quot;https://www.wikidata.org/wiki/Q10531425&quot; target=&quot;_blank&quot;&gt;Q10531425&lt;/a&gt;&lt;br&gt;         OSM: &lt;a href=&quot;https://www.openstreetmap.org/way/43002332&quot; target=&quot;_blank&quot;&gt;              way/43002332              &lt;/a&gt;&lt;br&gt;         NVRID: 2001199&lt;br&gt;         Status: True     &lt;/div&gt;`)[0];
#                 popup_ecd069301c8cc397365ac23ef8f536db.setContent(html_2a4b36c26dfd28de7b7927a7a177165c);
#
#
#
#         circle_marker_f377b26f9d13fd12e40a3dd1afb81c1b.bindPopup(popup_ecd069301c8cc397365ac23ef8f536db)
#         ;
#
#
#
#
#             var circle_marker_6129f9ee085af49619bc26c84550d2c4 = L.circleMarker(
#                 [60.329444439999996, 15.066944439999999],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &qu

# %% [markdown]
# ## Create quickstatement file

# %%
matches = matches.reset_index(drop=True)

# QID
matches["qid"] = matches["wd"].str.split("/").str[-1]

# only matched rows
qs_df = matches[matches["status"]].copy()

# clean id
qs_df["osm_id"] = qs_df["id"].astype(int) 

lines = []

for _, r in qs_df.iterrows():
    
    if r["type"] == "relation":
        lines.append(f'{r.qid}|P402|"{r.osm_id}"')
        
    elif r["type"] == "way":
        lines.append(f'{r.qid}|P10689|"{r.osm_id}"')
with open("osm_ids.qs", "w") as f:
    f.write("\n".join(lines))

print("QuickStatements file created:", len(lines), "statements")
# Out:
# QuickStatements file created: 1078 statements
